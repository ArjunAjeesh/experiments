# %%
from matplotlib import pyplot as p
import numpy as np

# %%
x=np.array([10,20])
y=np.array([20,40])

# %%
p.plot(x,y)

# %%
p.plot(x,y,"+")

# %%
a=np.array([10,30,50,60])
b=np.array([100,200,300,400])

# %%
p.plot(a,b,"*:m")

# %%
p.plot(b)

# %%
p.plot(x,y,"*:k")

# %%
p.plot(x,y,"*-m")

# %%
p.plot(a,b,"*--r")

# %%
p.plot(a,b,"*--r",ms=50)

# %%
p.plot(a,b,"*--r",ms=20,mfc='m')

# %%
p.plot(a,b,"1--r",ms=50)

# %%
p.plot(a,b,"v:r",ms=10)

# %%
#create a array with 10 points. plot it to the corresponding array of 10 points such that line is dotted ,square marker ,color of marker is pink and marker face color will be purple

# %%
z=np.array([10,25,40,45,50,70,80,85,95,99])

# %%
p.plot(z)

# %%
p.plot(z,"s:m",mfc='hotpink',ms=10,mec='red')

# %%
age=[3,4,55,78,2,10]
m=min(age)
m
# Out:
# 2

# %%
def binning(data):
    maximum_value=max(data)
    minimum_value=min(data)
    print("maximum value=",maximum_value)
    print("minimum value=",minimum_value)
    #child,teen,adult,old
    child=[] #empty list
    teen=[]
    adult=[]
    old=[]
    
    #for i in range(0,len(data)):
    for i in data:
        if i<=12:
            child.append(i)
        elif i>12 and i<20:
            teen.append(i)
        elif i>=20 and i<45:
            adult.append(i)
        elif i>=45:
            old.append(i)
    print("bin of children :",child)
    print("bin of teen:",teen)
    print("bin of adult:",adult)
    print("bin of old people:",old)
    
age=[10,2,14,23,12,46,67,30,20]
binning(age)
# Out:
# maximum value= 67
# minimum value= 2
# bin of children : [10, 2, 12]
# bin of teen: [14]
# bin of adult: [23, 30, 20]
# bin of old people: [46, 67]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_excel(r"C:\Users\ARJUN\OneDrive\Desktop\dataset.xlsx")

# %%
data.head
# Out:
# <bound method NDFrame.head of    USN  Name  Marks
# 0     1    A     45
# 1     2    B     10
# 2     3    C     22
# 3     4    D     27
# 4     5    E     32
# 5     6    F     48
# 6     7    G     38>

# %%
Marks=data.Marks

# %%
Marks
# Out:
# 0    45
# 1    10
# 2    22
# 3    27
# 4    32
# 5    48
# 6    38
# Name: Marks, dtype: int64

# %%
plt.hist(Marks,bins=[10,15,20,25,30,35,40,45,50],color='red')
plt.xlabel("Marks")
plt.title('Histogram of Marks')
plt.show()
